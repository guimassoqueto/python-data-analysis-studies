# %%
 import pandas as pd

# %%
nba = pd.read_csv('../nba.csv')

# %% [markdown]
# Broadcasting a value:

# %%
nba.insert(loc=5, column='AgePlusTen', value=nba['Age']+10)

# %%
nba.head(n=5)
# Out:
#             Name            Team  Number Position   Age  AgePlusTen Height  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0        35.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0        35.0    6-6
# 2   John Holland  Boston Celtics    30.0       SG  27.0        37.0    6-5
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0        32.0    6-5
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0        39.0   6-10
#
#    Weight            College     Salary
# 0   180.0              Texas  7730337.0
# 1   235.0          Marquette  6796117.0
# 2   205.0  Boston University        NaN
# 3   185.0      Georgia State  1148640.0
# 4   231.0                NaN  5000000.0

# %% [markdown]
# Or...

# %%
nba.insert(loc=6, column='AgePlusTwenty', value=nba['Age'].add(20))

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age  AgePlusTen  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0        35.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0        35.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0        37.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0        32.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0        39.0
#
#    AgePlusTwenty Height  Weight            College     Salary
# 0           45.0    6-2   180.0              Texas  7730337.0
# 1           45.0    6-6   235.0          Marquette  6796117.0
# 2           47.0    6-5   205.0  Boston University        NaN
# 3           42.0    6-5   185.0      Georgia State  1148640.0
# 4           49.0   6-10   231.0                NaN  5000000.0
